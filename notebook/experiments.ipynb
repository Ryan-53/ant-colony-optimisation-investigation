# %%
import pandas as pd
exp = pd.read_csv('experiments_ms.csv')

# %%
exp.head()
# Out:
#    experiment run  colony_size  burma_colony  brazil_colony  evaporation_rate  \
# 0             0.0         10.0        3548.0        29552.0              0.25
# 1             1.0         25.0        3439.0        27235.0              0.40
# 2             2.0         50.0        3386.0        26865.0              0.50
# 3             3.0         75.0        3045.0        26570.0              0.60
# 4             4.0        100.0        3138.0        27375.0              0.70
#
#    burma_evap  brazil_evap    q  burma_q  brazil_q  ... alpha-beta  burma_ab  \
# 0      3338.0      27658.0  0.5   3121.0   27791.0  ...    0.5 - 3    3199.0
# 1      3232.0      27000.0  1.0   3382.0   27148.0  ...      1 - 2    3230.0
# 2      3045.0      26570.0  2.0   3222.0   27009.0  ...      2 - 1    3293.0
# 3      3214.0      27124.0  3.0   3103.0   26737.0  ...        NaN       NaN
# 4      3467.0      27347.0  4.0   3193.0   27999.0  ...        NaN       NaN
#
# ...

# %% [markdown]
# **1.** Colony Size

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(figsize=(12,6))

exp.plot(ax=axs, x='colony_size',
                 y='burma_colony',
                 #grid=True,
                 label="Burma")

exp.plot(ax=axs, x='colony_size',
                 y='brazil_colony',
                 secondary_y=True,
                 label="Brazil")

plt.title('Colony size experiment')
axs.set_xlabel("Colony size")
axs.set_ylabel('Median Best Quality Found (Burma)')
plt.ylabel('Median Best Quality Found (Brazil)')
# Out:
# Text(0, 0.5, 'Median Best Quality Found (Brazil)')

# %% [markdown]
# **2.** Evaporation rate

# %%
fig, axs = plt.subplots(figsize=(12,6))

exp.plot(ax=axs, x='evaporation_rate',
                 y='burma_evap',
                 grid=True,
                 label="Burma")

exp.plot(ax=axs, x='evaporation_rate',
                 y='brazil_evap',
                 secondary_y=True,
                 label="Brazil")

plt.title('Evaporation rate experiment')
axs.set_xlabel("Evaporation rate")
axs.set_ylabel('Median Best Quality Found (Burma)')
plt.ylabel('Median Best Quality Found (Brazil)')
# Out:
# Text(0, 0.5, 'Median Best Quality Found (Brazil)')

# %% [markdown]
# **3.** Alpha and Beta

# %%
fig, axs = plt.subplots(figsize=(12,6))

exp.plot(ax=axs, x='alpha-beta',
                 y='burma_ab',
                 #grid=True,
                 label="Burma")

exp.plot(ax=axs, x='alpha-beta',
                 y='brazil_ab',
                 secondary_y=True,
                 label="Brazil")

plt.title('Alpha and Beta experiment')
axs.set_xlabel("Alpha - Beta")
axs.set_ylabel('Median Best Quality Found (Burma)')
plt.ylabel('Median Best Quality Found (Brazil)')
# Out:
# Text(0, 0.5, 'Median Best Quality Found (Brazil)')

# %% [markdown]
# **4.** Starting Point

# %%
fig, axs = plt.subplots(figsize=(12,6))

exp.plot(ax=axs, x='starting_point',
                 y='burma_start',
                 grid=True,
                 label="Burma")

exp.plot(ax=axs, x='starting_point',
                 y='brazil_start',
                 secondary_y=True,
                 label="Brazil")

plt.title('Starting point experiment')
axs.set_xlabel("Starting point")
axs.set_ylabel('Median Best Quality Found (Burma)')
plt.ylabel('Median Best Quality Found (Brazil)')
# Out:
# Text(0, 0.5, 'Median Best Quality Found (Brazil)')

# %% [markdown]
# **5.** Heuristics

# %%
fig, axs = plt.subplots(figsize=(12,6))

exp.plot(ax=axs, x='q',
                 y='burma_q',
                 grid=True,
                 label="Burma")

exp.plot(ax=axs, x='q',
                 y='brazil_q',
                 secondary_y=True,
                 label="Brazil")

plt.title('Heuristic function Q/d experiment')
axs.set_xlabel("Q")
axs.set_ylabel('Median Best Quality Found (Burma)')
plt.ylabel('Median Best Quality Found (Brazil)')
# Out:
# Text(0, 0.5, 'Median Best Quality Found (Brazil)')

# %% [markdown]
# **6.** MMAS (Min-Max) ACO Variation

# %%
fig, axs = plt.subplots(figsize=(12,6))

exp.plot(ax=axs, x='min-max',
                 y='burma_mmas',
                 grid=True,
                 label="Burma")

exp.plot(ax=axs, x='min-max',
                 y='brazil_mmas',
                 secondary_y=True,
                 label="Brazil")

plt.title('MMAS (Min-Max) ACO Variation')
axs.set_xlabel("Min-Max")
axs.set_ylabel('Median Best Quality Found (Burma)')
plt.ylabel('Median Best Quality Found (Brazil)')
# Out:
# Text(0, 0.5, 'Median Best Quality Found (Brazil)')

# %% [markdown]
# **7.** Rank-based (ASrank) ACO Variation

# %%
fig, axs = plt.subplots(figsize=(12,6))

exp.plot(ax=axs, x='top_ranked',
                 y='burma_rank',
                 grid=True,
                 label="Burma")

exp.plot(ax=axs, x='top_ranked',
                 y='brazil_rank',
                 secondary_y=True,
                 label="Brazil")

plt.title('Rank-based (ASrank) ACO Variation')
axs.set_xlabel("Top ? Ranked")
axs.set_ylabel('Median Best Quality Found (Burma)')
plt.ylabel('Median Best Quality Found (Brazil)')
# Out:
# Text(0, 0.5, 'Median Best Quality Found (Brazil)')
